# %% [markdown]
# <h1>Class</h1>

# %%
# Create a class called democlass
# Remember class name always starts with capital letter : Democlass 
class Democlass:
    pass

# %%
#Create a object of a class
object = Democlass()
help(Democlass)
dir(Democlass)
# Out:
# Help on class Democlass in module __main__:
#
# class Democlass(builtins.object)
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
# Create another function named Display
class Display:
    
    def setValue(self,a,b):
        self.a = a
        self.b = b
        
    def displayMessage(self):
        print("Welcome User : ")
        print(f"The addition of two number {self.a+self.b}" )

#if we dont wrte self.a it will throw error :
''''AttributeError                            Traceback (most recent call last)
<ipython-input-30-6fe5491bffbd> in <module>
      1 d1 = Display()
      2 d1.setValue(10,20)
----> 3 d1.displayMessage()

AttributeError: 'Display' object has no attribute 'displayMessage''''

# %%
d1 = Display()
d1.setValue(10,20)
d1.displayMessage()
# Out:
# Welcome User :
# The addition of two number 30
