# %%
class Calc:
    
    def __init__(self, value=0):
        self.value = value
    
    def __add__(self, other):
        temp = Calc()
        temp.value = self.value + other.value
        return temp
    
    def __mul__(self, other):
        temp = Calc()
        temp.value = self.value * other.value
        return temp
    
    def __sub__(self, other):
        temp = Calc()
        temp.value = self.value - other.value
        return temp
    
    def __truediv__(self, other):
        temp = Calc()
        temp.value = self.value / other.value
        return temp
    
    def display(self):
        print("Result :", self.value)


# ---------------- MENU PROGRAM ----------------
while True:
    print("\n===== MENU =====")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "5":
        print("Thank you!")
        break

    n1 = float(input("Enter first number: "))
    n2 = float(input("Enter second number: "))
    
    a = Calc(n1)
    b = Calc(n2)
    
    if choice == "1":
        ans = a + b
    elif choice == "2":
        ans = a - b
    elif choice == "3":
        ans = a * b
    elif choice == "4":
        if b.value == 0:
            print("Cannot divide by zero!")
            continue
        ans = a / b
    else:
        print("Invalid choice!")
        continue

    ans.display()
# Out:
# ===== MENU =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice: 1
# Enter first number: 1000
# Enter second number: 2000
# Result : 3000.0
#
# ===== MENU =====
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice: 2
# Enter first number: 100-65
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a40f994b38a0> in <module>
#      43         break
#      44
# ---> 45     n1 = float(input("Enter first number: "))
#      46     n2 = float(input("Enter second number: "))
#      47
#
# ValueError: could not convert string to float: '100-65'
